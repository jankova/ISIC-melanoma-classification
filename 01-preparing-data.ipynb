# %% [markdown]
# # Dataset
# We downloaded data in tfrec format with decreased resolution 256x256 prepared by Chris Deotte in the following notebook:
#
# https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/173639
#
# Namely, we use the 2020 Dataset:
# https://www.kaggle.com/cdeotte/melanoma-256x256
#
# and also consider an additional sample of 4000 malignant-only images:
#
# https://www.kaggle.com/cdeotte/malignant-v2-256x256

# %% [markdown]
# ## Extracting the zipped tfrecords

# %%
# 2020 Dataset
# !unzip data/preprocessed_tfr/archive.zip -d data/preprocessed_tfr/tfr_records_256

# %%
# Malignant 4000 examples
# !unzip data/preprocessed_tfr/archive_malign.zip -d data/preprocessed_tfr/tfr_records_256_malig

# %% [markdown]
# # Exploring data

# %%
import config
import pandas as pd

train = pd.read_csv(config.TRAIN_PATH + 'train.csv')
    
print('Train samples: %d' % len(train))
    
pos = len(train[train['target'] == 1]) * 2 + 1627 + 580
neg = len(train[train['target'] == 0]) + 8388

print(f"Number of malignant: {pos}")
print(f"Number of benign: {neg}")

display(train.head())
# Out:
# Train samples: 33126
# Number of malignant: 3375
# Number of benign: 40930
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_2637011  IP_7279968    male        45.0                     head/neck
# 1  ISIC_0015719  IP_3075186  female        45.0               upper extremity
# 2  ISIC_0052212  IP_2842074  female        50.0               lower extremity
# 3  ISIC_0068279  IP_6890425  female        45.0                     head/neck
# 4  ISIC_0074268  IP_8723313  female        55.0               upper extremity
#
#   diagnosis benign_malignant  target  tfrecord  width  height  patient_code
# 0   unknown           benign       0         0   6000    4000             0
# 1   unknown           benign       0         0   6000    4000             1
# 2     nevus           benign       0         6   1872    1053             2
# 3   unknown           benign       0         0   1872    1053             3
# 4   unknown           benign       0        11   6000    4000             4

# %%
train_malig_1 = pd.read_csv(config.TRAIN_PATH_MALIG + 'train_malig_1.csv')
train_malig_2 = pd.read_csv(config.TRAIN_PATH_MALIG + 'train_malig_2.csv')
train_malig_3 = pd.read_csv(config.TRAIN_PATH_MALIG + 'train_malig_3.csv')

train_malig = pd.concat([train_malig_1, train_malig_2, train_malig_3], axis = 0)
train_malig.to_csv(config.TRAIN_PATH_MALIG + 'train_malig_all.csv', index = False)
train_malig
# Out:
#         image_name  patient_id     sex  age_approx  \
# 0     ISIC_0149568  IP_0962375  female        55.0
# 1     ISIC_0188432  IP_0135517  female        50.0
# 2     ISIC_0207268  IP_7735373    male        55.0
# 3     ISIC_0232101  IP_8349964    male        65.0
# 4     ISIC_0247330  IP_3232631  female        65.0
# ...            ...         ...     ...         ...
# 2807  ISIC_0073203          -1    male        65.0
# 2808  ISIC_0073237          -1  female        45.0
# 2809  ISIC_0073238          -1  female        45.0
# 2810  ISIC_0073241          -1    male        60.0
# 2811  ISIC_0073249          -1    male        70.0
#
#      anatom_site_general_challenge diagnosis benign_malignant  target  \
# 0                  upper extremity  melanoma        malignant       1
# 1                  upper extremity  melanoma        malignant       1
# 2                            torso  melanoma        malignant       1
# 3                            torso  melanoma        malignant       1
# 4                  lower extremity  melanoma        malignant       1
# ...                            ...       ...              ...     ...
# 2807                anterior torso       MEL        malignant       1
# 2808               lower extremity       MEL        malignant       1
# 2809               upper extremity       MEL        malignant       1
# 2810                   palms/soles       MEL        malignant       1
# 2811               lower extremity       MEL        malignant       1
#
#       tfrecord  width  height  patient_code source  ext
# 0            0   6000    4000          80.0    NaN  NaN
# 1            5   3264    2448          47.0    NaN  NaN
# 2            3   6000    4000         262.0    NaN  NaN
# 3            9   4288    2848         225.0    NaN  NaN
# 4           10   6000    4000         363.0    NaN  NaN
# ...        ...    ...     ...           ...    ...  ...
# 2807        33   1024    1024           NaN    NaN  NaN
# 2808        41   1024    1024           NaN    NaN  NaN
# 2809        41   1024    1024           NaN    NaN  NaN
# 2810        43   1024    1024           NaN    NaN  NaN
# 2811        39   1024    1024           NaN    NaN  NaN
#
# [3976 rows x 14 columns]
